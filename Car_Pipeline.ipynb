# %%
import pandas as pd

# %%
df=pd.read_csv('cars.csv')

# %%
df.head(2)
# Out:
#    Car_ID   Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1  Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2   Honda    Civic  2019              40000    Petrol    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000

# %%
df.isnull().sum()
# Out:
# Car_ID               0
# Brand                0
# Model                0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
X=df.drop('Price',axis=1)
Y=df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=48)

# %%
import numpy as np
feat_num=X.select_dtypes(include=np.number).columns
feat_cat=X.select_dtypes(exclude=np.number).columns

# %%
feat_num,feat_cat
# Out:
# (Index(['Car_ID', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power',
#         'Seats'],
#        dtype='object'),
#  Index(['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Owner_Type'], dtype='object'))

# %%
#Create a pipeline
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
#Numeric Pipeline
num_pipe=Pipeline([
    ('imputer',KNNImputer()),
    ('std_scl',StandardScaler())
])

# %%
#Categorical Pipeline
cat_pipe=Pipeline([
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('one_hot',OneHotEncoder())
])

# %%
from sklearn.compose import ColumnTransformer

# %%
data_pipeline=ColumnTransformer([
    ('numeric',num_pipe,feat_num),
    ('categorical',cat_pipe,feat_cat),
],remainder='passthrough')

# %%
data_pipeline
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('numeric',
#                                  Pipeline(steps=[('imputer', KNNImputer()),
#                                                  ('std_scl',
#                                                   StandardScaler())]),
#                                  Index(['Car_ID', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power',
#        'Seats'],
#       dtype='object')),
#                                 ('categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('one_hot', OneHotEncoder())]),
#                                  Index(['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Owner_Type'], dtype='object'))])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
full_pipe=Pipeline([
    ('pre_process',data_pipeline),
    ('model',RandomForestRegressor())
])

# %%
full_pipe
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('std_scl',
#                                                                    StandardScaler())]),
#                                                   Index(['Car_ID', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power',
#        'Seats'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one_hot',
#                                                                    OneHotEncoder())]),
#                                                   Index(['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Owner_Type'], dtype='object'))])),
#                 ('model', RandomForestRegressor())])

# %%
full_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('std_scl',
#                                                                    StandardScaler())]),
#                                                   Index(['Car_ID', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power',
#        'Seats'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one_hot',
#                                                                    OneHotEncoder())]),
#                                                   Index(['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Owner_Type'], dtype='object'))])),
#                 ('model', RandomForestRegressor())])

# %%
X_train['Model'].unique()
# Out:
# array(['Mustang', 'Innova', 'Altroz', 'Civic', 'Santro', 'Ameo', 'GLC',
#        'Ertiga', 'EcoSport', 'Safari', 'Venue', 'A5', 'S-Cross', 'Swift',
#        'Polo', 'A3', 'GLE', 'C-Class', 'A6', 'X3', 'Creta', 'BR-V',
#        'Vento', 'Verna', 'Harrier', '7 Series', 'Tiguan', 'X5', 'Camry',
#        'Tigor', 'T-Roc', 'WR-V', 'Tiago', 'Passat', 'Figo', 'Yaris',
#        'XUV300', '5 Series', 'E-Class', 'Aspire', 'City', 'Innova Crysta',
#        '3 Series', 'Q7', 'Elantra', 'GLA', 'Scorpio', 'Fortuner',
#        'Corolla'], dtype=object)

# %%
X_test['Model'].unique()
# Out:
# array(['A5', 'Nexon', 'Vitara', 'X1', 'Endeavour', 'Santro', 'Elantra',
#        'A4', 'EcoSport', 'Passat', 'Yaris', 'Q7', 'X5', 'Thar', 'Tiago',
#        'Q3', 'Innova Crysta', 'Altroz', '7 Series', 'Ranger', 'Sonata',
#        'T-Roc', '3 Series', 'Fortuner', 'Verna', 'C-Class', 'GLE'],
#       dtype=object)

# %%
full_pipe.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 full_pipe.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:600, in Pipeline.predict(self, X, **params)
#     598 if not _routing_enabled():
#     599     for _, name, transform in self._iter(with_final=False):
# --> 600         Xt = transform.transform(Xt)
#     601     return self.steps[-1][1].predict(Xt, **params)
#     603 # metadata routing enabled
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:1076, in ColumnTransformer.transform(self, X, **params)
#    1073 else:
#    1074     routed_params = self._get_empty_routing()
# -> 1076 Xs = self._call_func_on_transformers(
#    1077     X,
#    1078     None,
#    1079     _transform_one,
#    1080     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1081     routed_params=routed_params,
#    1082 )
#    1083 self._validate_output(Xs)
#    1085 if not Xs:
#    1086     # All transformers are None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:885, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     873             extra_args = {}
#     874         jobs.append(
#     875             delayed(func)(
#     876                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     882             )
#     883         )
# --> 885     return Parallel(n_jobs=self.n_jobs)(jobs)
#     887 except ValueError as e:
#     888     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:1290, in _transform_one(transformer, X, y, weight, params)
#    1268 def _transform_one(transformer, X, y, weight, params=None):
#    1269     """Call transform and apply weight to output.
#    1270
#    1271     Parameters
#    (...)
#    1288         This should be of the form ``process_routing()["step_name"]``.
#    1289     """
# -> 1290     res = transformer.transform(X, **params.transform)
#    1291     # if we have a weight for this transformer, multiply output
#    1292     if weight is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:903, in Pipeline.transform(self, X, **params)
#     901 Xt = X
#     902 for _, name, transform in self._iter():
# --> 903     Xt = transform.transform(Xt, **routed_params[name].transform)
#     904 return Xt
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:1024, in OneHotEncoder.transform(self, X)
#    1019 # validation of X happens in _check_X called by _transform
#    1020 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1021     "ignore",
#    1022     "infrequent_if_exist",
#    1023 }
# -> 1024 X_int, X_mask = self._transform(
#    1025     X,
#    1026     handle_unknown=self.handle_unknown,
#    1027     force_all_finite="allow-nan",
#    1028     warn_on_unknown=warn_on_unknown,
#    1029 )
#    1031 n_samples, n_features = X_int.shape
#    1033 if self._drop_idx_after_grouping is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:214, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     209 if handle_unknown == "error":
#     210     msg = (
#     211         "Found unknown categories {0} in column {1}"
#     212         " during transform".format(diff, i)
#     213     )
# --> 214     raise ValueError(msg)
#     215 else:
#     216     if warn_on_unknown:
#
# ValueError: Found unknown categories ['X1', 'Ranger', 'Vitara', 'A4', 'Thar', 'Sonata', 'Q3', 'Nexon', 'Endeavour'] in column 1 during transform
